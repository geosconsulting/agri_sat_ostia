# %%
import matplotlib.pyplot as plt
import geopandas as gpd
import rasterio
import rasterio.plot as rioplt

# %%
img = rasterio.open('T32TQM_20210301/T32TQM_20210301T100031_B02_20m.jp2')
clip_shape = gpd.read_file('cut_poly.shp')

# %%
img.crs
# Out:
# CRS.from_epsg(32632)

# %%
img.bounds
# Out:
# BoundingBox(left=699960.0, bottom=4590240.0, right=809760.0, top=4700040.0)

# %%
clip_shape.crs
# Out:
# <Derived Projected CRS: EPSG:32632>
# Name: WGS 84 / UTM zone 32N
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Between 6°E and 12°E, northern hemisphere between equator and 84°N, onshore and offshore. Algeria. Austria. Cameroon. Denmark. Equatorial Guinea. France. Gabon. Germany. Italy. Libya. Liechtenstein. Monaco. Netherlands. Niger. Nigeria. Norway. Sao Tome and Principe. Svalbard. Sweden. Switzerland. Tunisia. Vatican City State.
# - bounds: (6.0, 0.0, 12.0, 84.0)
# Coordinate Operation:
# - name: UTM zone 32N
# - method: Transverse Mercator
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
clip_shape.bounds
# Out:
#             minx          miny           maxx          maxy
# 0  771515.771014  4.627540e+06  778587.793572  4.633525e+06

# %%
fig, ax = plt.subplots(figsize=(12, 9))
rioplt.show(img, ax=ax, cmap="Greys")
clip_shape.plot(ax=ax, facecolor="red", edgecolor="red", linewidth=2)
# Out:
# <AxesSubplot:>

# %%
clip_shape.plot(facecolor="red", edgecolor="red", linewidth=2)
# Out:
# <AxesSubplot:>
